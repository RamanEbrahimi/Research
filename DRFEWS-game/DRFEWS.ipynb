# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
CDL = pd.read_csv('/Users/macbook/Desktop/DRFEWS-data/CDL_County_Cellwise_55141.csv')
NLCD = pd.read_csv('/Users/macbook/Desktop/DRFEWS-data/NLCD_County_Cellwise_SpatialJoin_55141.csv')
# Out:
# /var/folders/hs/y116vr4j4yg5fcthw_l99c5r0000gn/T/ipykernel_79477/1795110544.py:2: DtypeWarning: Columns (25,26,28,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   NLCD = pd.read_csv('/Users/macbook/Desktop/DRFEWS-data/NLCD_County_Cellwise_SpatialJoin_55141.csv')

# %% [markdown]
# # NLCD

# %%
NLCD.head()
# Out:
#           cell  GEOID  CSAFP  CBSAFP    LU_2001    LU_2004    LU_2006  \
# 0  139758948.0  55141    554   49220  Developed  Developed  Developed
# 1  139758949.0  55141    554   49220   Cropland   Cropland   Cropland
# 2  139758950.0  55141    554   49220     Forest     Forest     Forest
# 3  139758951.0  55141    554   49220     Forest     Forest     Forest
# 4  139758952.0  55141    554   49220     Forest     Forest     Forest
#
#      LU_2008    LU_2011    LU_2013  ...      MaxTexture         x          y  \
# 0  Developed  Developed  Developed  ...  loamy-skeletal  472410.0  2404200.0
# 1   Cropland   Cropland   Cropland  ...  loamy-skeletal  472440.0  2404200.0
# 2     Forest     Forest     Forest  ...  loamy-skeletal  472410.0  2404170.0
# 3     Forest     Forest     Forest  ...      fine-loamy  472440.0  2404170.0
# 4     Forest     Forest     Forest  ...      fine-loamy  472470.0  2404170.0
#
#    Slope_Degrees  FIPS_UA00 Name_UA00  Type_UA00 FIPS_UA10  Name_UA10  \
# 0       0.017531        NaN       NaN        NaN       NaN        NaN
# 1       0.016046        NaN       NaN        NaN       NaN        NaN
# 2       0.020382        NaN       NaN        NaN       NaN        NaN
# 3       0.029940        NaN       NaN        NaN       NaN        NaN
# 4       0.031191        NaN       NaN        NaN       NaN        NaN
#
#    Type_UA10
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 30 columns]

# %%
NLCD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2267698 entries, 0 to 2267697
# Data columns (total 30 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   cell           float64
#  1   GEOID          int64
#  2   CSAFP          int64
#  3   CBSAFP         int64
#  4   LU_2001        object
#  5   LU_2004        object
#  6   LU_2006        object
#  7   LU_2008        object
#  8   LU_2011        object
#  9   LU_2013        object
#  10  LU_2016        object
#  11  LU_2019        object
#  12  FIPS_cnty      int64
#  13  FIPS_csa18     int64
#  14  FIPS_cbsa18    int64
#  15  AREASYMBOL     object
#  16  SPATIALVER     int64
#  17  MUSYM          object
#  18  mapunit_key    int64
#  19  nccpi          float64
#  20  MaxTexture     object
#  21  x              float64
#  22  y              float64
#  23  Slope_Degrees  float64
#  24  FIPS_UA00      float64
#  25  Name_UA00      object
#  26  Type_UA00      object
#  27  FIPS_UA10      float64
#  28  Name_UA10      object
#  29  Type_UA10      object
# dtypes: float64(7), int64(8), object(15)
# memory usage: 519.0+ MB

# %%
print(NLCD['LU_2006'].unique())
# Out:
# ['Developed' 'Cropland' 'Forest' 'Pasture' 'Wetlands' 'Other']

# %% [markdown]
# # CDL

# %%
CDL.head()
# Out:
#           cell       x        y  GEOID           LU_2008           LU_2009  \
# 0  139758943.0  486270  2426400  55141  Deciduous Forest  Deciduous Forest
# 1  139758944.0  486300  2426400  55141  Deciduous Forest  Deciduous Forest
# 2  139758945.0  486330  2426400  55141  Deciduous Forest  Deciduous Forest
# 3  139758946.0  486360  2426400  55141              Corn  Deciduous Forest
# 4  139758947.0  486390  2426400  55141  Deciduous Forest  Deciduous Forest
#
#             LU_2010           LU_2011           LU_2012           LU_2013  \
# 0  Deciduous Forest  Deciduous Forest  Deciduous Forest  Deciduous Forest
# 1  Deciduous Forest  Deciduous Forest  Deciduous Forest  Deciduous Forest
# 2  Deciduous Forest  Deciduous Forest  Deciduous Forest  Deciduous Forest
# 3  Deciduous Forest  Deciduous Forest  Deciduous Forest  Deciduous Forest
# 4  Deciduous Forest  Deciduous Forest  Deciduous Forest  Deciduous Forest
#
#    ... LU_2009_DRFEWS LU_2010_DRFEWS LU_2011_DRFEWS LU_2012_DRFEWS  \
# 0  ...         Forest         Forest         Forest         Forest
# 1  ...         Forest         Forest         Forest         Forest
# 2  ...         Forest         Forest         Forest         Forest
# 3  ...         Forest         Forest         Forest         Forest
# 4  ...         Forest         Forest         Forest         Forest
#
#   LU_2013_DRFEWS LU_2014_DRFEWS LU_2015_DRFEWS LU_2016_DRFEWS LU_2017_DRFEWS  \
# 0         Forest         Forest         Forest         Forest         Forest
# 1         Forest         Forest         Forest         Forest         Forest
# 2         Forest         Forest         Forest         Forest         Forest
# 3         Forest         Forest         Forest         Forest         Forest
# 4         Forest         Forest         Forest         Forest         Forest
#
#   LU_2018_DRFEWS
# 0         Forest
# 1         Forest
# 2         Forest
# 3         Forest
# 4         Forest
#
# [5 rows x 26 columns]

# %%
not_needed = CDL.columns[15:]
CDL.drop(not_needed, axis=1, inplace=True)
CDL.head()
# Out:
#           cell       x        y  GEOID           LU_2008           LU_2009  \
# 0  139758943.0  486270  2426400  55141  Deciduous Forest  Deciduous Forest
# 1  139758944.0  486300  2426400  55141  Deciduous Forest  Deciduous Forest
# 2  139758945.0  486330  2426400  55141  Deciduous Forest  Deciduous Forest
# 3  139758946.0  486360  2426400  55141              Corn  Deciduous Forest
# 4  139758947.0  486390  2426400  55141  Deciduous Forest  Deciduous Forest
#
#             LU_2010           LU_2011           LU_2012           LU_2013  \
# 0  Deciduous Forest  Deciduous Forest  Deciduous Forest  Deciduous Forest
# 1  Deciduous Forest  Deciduous Forest  Deciduous Forest  Deciduous Forest
# 2  Deciduous Forest  Deciduous Forest  Deciduous Forest  Deciduous Forest
# 3  Deciduous Forest  Deciduous Forest  Deciduous Forest  Deciduous Forest
# 4  Deciduous Forest  Deciduous Forest  Deciduous Forest  Deciduous Forest
#
#             LU_2014           LU_2015           LU_2016           LU_2017  \
# 0  Deciduous Forest  Deciduous Forest  Deciduous Forest  Deciduous Forest
# 1  Deciduous Forest  Deciduous Forest  Deciduous Forest  Deciduous Forest
# 2  Deciduous Forest  Deciduous Forest  Deciduous Forest  Deciduous Forest
# 3  Deciduous Forest  Deciduous Forest  Deciduous Forest  Deciduous Forest
# 4  Deciduous Forest  Deciduous Forest  Deciduous Forest  Deciduous Forest
#
#             LU_2018
# 0  Deciduous Forest
# 1  Deciduous Forest
# 2  Deciduous Forest
# 3  Deciduous Forest
# 4  Deciduous Forest

# %%
print(CDL['LU_2018'].unique())
# Out:
# ['Deciduous Forest' 'Developed/Open Space' 'Other Hay/Non Alfalfa'
#  'Alfalfa' 'Grassland/Pasture' 'Oats' 'Corn' 'Woody Wetlands'
#  'Developed/Low Intensity' 'Shrubland' 'Herbaceous Wetlands'
#  'Clover/Wildflowers' 'Soybeans' 'Evergreen Forest' 'Winter Wheat'
#  'Mixed Forest' 'Fallow/Idle Cropland' 'Open Water' 'Rye' 'Herbs'
#  'Christmas Trees' 'Developed/Med Intensity' 'Barren'
#  'Developed/High Intensity' 'Barley' 'Triticale' 'Dry Beans' 'Potatoes'
#  'Spring Wheat' 'Carrots' 'Peas' 'Sod/Grass Seed' 'Sorghum' 'Apples'
#  'Cherries' 'Cucumbers' 'Sweet Potatoes' 'Strawberries'
#  'Misc Vegs & Fruits' 'Cabbage' 'Squash' 'Dbl Crop WinWht/Soybeans'
#  'Dbl Crop WinWht/Corn' 'Camelina' 'Other Crops']

# %%
print(CDL.shape)
print(NLCD.shape)
# Out:
# (2332210, 15)
# (2267698, 30)

# %%
# Initialize empty data frames to store similar and dissimilar rows
similar_df = pd.DataFrame()
dissimilar_df = pd.DataFrame()

# Loop through each row of the data frame
for index, row in CDL.iterrows():
    
    # Check if inputs in columns 4-14 are the same
    if row[4:15].nunique() == 1:
        # If they're the same, add the row to the similar data frame
        similar_df = pd.concat([similar_df, row.to_frame().transpose()])
    else:
        # If they're not the same, add the row to the dissimilar data frame
        dissimilar_df = pd.concat([dissimilar_df, row.to_frame().transpose()])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/hs/y116vr4j4yg5fcthw_l99c5r0000gn/T/ipykernel_79477/2397435810.py in <module>
#      12     else:
#      13         # If they're not the same, add the row to the dissimilar data frame
# ---> 14         dissimilar_df = pd.concat([dissimilar_df, row.to_frame().transpose()])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     358     )
#     359
# --> 360     return op.get_result()
#     361
#     362
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     593                 mgrs_indexers.append((obj._mgr, indexers))
#     594
# --> 595             new_data = concatenate_managers(
#     596                 mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     597             )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/concat.py in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     230                 #  we can use np.concatenate, which is more performant
#     231                 #  than concat_compat
# --> 232                 values = np.concatenate(vals, axis=1)
#     233             else:
#     234                 # TODO(EA2D): special-casing not needed with 2D EAs
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:
